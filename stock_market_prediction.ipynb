# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = '/content/TSLA.csv'

# %%
df  = pd.read_csv(url)

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-30   42.161331   43.391998   41.200001   42.720669   42.720669
# 1    2020-01-31   42.666668   43.533333   42.167999   43.371334   43.371334
# 2    2020-02-03   44.912666   52.409332   44.901333   52.000000   52.000000
# 3    2020-02-04   58.863998   64.599335   55.591999   59.137333   59.137333
# 4    2020-02-05   54.883999   56.398666   46.940666   48.980000   48.980000
# ..          ...         ...         ...         ...         ...         ...
# 750  2023-01-23  135.869995  145.380005  134.270004  143.750000  143.750000
# 751  2023-01-24  143.000000  146.500000  141.100006  143.889999  143.889999
# 752  2023-01-25  141.910004  146.410004  138.070007  144.429993  144.429993
# 753  2023-01-26  159.970001  161.419998  154.759995  160.270004  160.270004
# 754  2023-01-27  162.429993  180.679993  161.169998  177.899994  177.899994
#
#         Volume
# 0    435085500
# 1    235789500
# ...

# %%
plt.figure(figsize=(12.5, 4.5))
plt.plot(df['Adj Close'], label = 'TSLA')
plt.title('Tesla Adj. close price history')
plt.xlabel('dates mentioned')
plt.ylabel('Adj. close price')
plt.show()

# %% [markdown]
# # New Section

# %%
SMA30 = pd.DataFrame()
SMA30['Adj Close Price'] = df['Adj Close'].rolling(window=30).mean()

SMA30
# Out:
#      Adj Close Price
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 750       133.468667
# 751       132.483666
# 752       131.329666
# 753       131.077999
# 754       131.642999
#
# [755 rows x 1 columns]

# %%
# moving 100 day average 
SMA100 = pd.DataFrame()
SMA100['Adj Close Price'] = df['Adj Close'].rolling(window=100).mean()
SMA100
# Out:
#      Adj Close Price
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 750         202.6287
# 751         201.2906
# 752         199.9788
# 753         198.8099
# 754         197.8868
#
# [755 rows x 1 columns]

# %%
plt.figure(figsize=(18.5, 7.5))
plt.plot(df['Adj Close'], label = 'TSLA')
plt.plot(SMA30['Adj Close Price'], label = 'SM30')
plt.plot(SMA100['Adj Close Price'], label = 'SM100')
plt.title('Tesla Adj. close price history')
plt.xlabel('dates mentioned')
plt.ylabel('Adj. close price')
plt.legend(loc='upper left')
plt.show()

# %%
data = pd.DataFrame()
data['TSLA'] = df['Adj Close']
data['SMA30'] = SMA30['Adj Close Price']
data['SMA100'] = SMA100['Adj Close Price']
data
# Out:
#            TSLA       SMA30    SMA100
# 0     42.720669         NaN       NaN
# 1     43.371334         NaN       NaN
# 2     52.000000         NaN       NaN
# 3     59.137333         NaN       NaN
# 4     48.980000         NaN       NaN
# ..          ...         ...       ...
# 750  143.750000  133.468667  202.6287
# 751  143.889999  132.483666  201.2906
# 752  144.429993  131.329666  199.9788
# 753  160.270004  131.077999  198.8099
# 754  177.899994  131.642999  197.8868
#
# [755 rows x 3 columns]

# %%
def buy_sell(data):
  sigPriceBuy = []
  sigPriceSell = []
  flag = -1
